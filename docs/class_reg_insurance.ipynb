# %% [markdown]
# Classification + regression on "medical insurance" dataset
#
# https://www.kaggle.com/datasets/pranavshinde36/medical-insurance-dataset

# %%
import pandas as pd

df = pd.read_csv("class_reg_insurance.csv")

df
